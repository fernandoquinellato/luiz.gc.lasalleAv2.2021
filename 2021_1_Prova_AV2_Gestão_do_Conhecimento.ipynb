# %% [markdown]
# DISCIPLINA: Gestão do Conhecimento	 PROFESSOR(A): Alex Salgado
# PERÍODO: 7o. TURNO: noite AVALIAÇÃO:
#
# ALUNO(A):Luiz Fernando Quinellato Cardoso de Souza
#
# GRAU: VISTO DO PROFESSOR:

# %% [markdown]
# # Questão 1 - valor (0,0)

# %% [markdown]
# *** Crie um repositório no Github e adicione este arquivo no mesmo
#
#
# 1.1 - Você deve escolher uma base de dados do Kaggle.
#
# A natureza desse dataset deve se encaixar em um problema que podemos resolver utilizando modelos de previsão de machine learning supervisionado de classificação.
#
# A partir desta base de dados do Kaggle, você vai treinar o modelo, fazer previsões e calcular a acurácia do mesmo, usando modelos e algoritmos que desejar.
#
# Obs1: Usar o Kaggle como fonte para o seu dataset obrigatoriamente.
# Obs2: Implementações idênticas ou bem parecidas pode levar a anulação da NOTA ou seja, ZERO!! Faça o melhor com sua equipe apenas.

# %% [markdown]
# 1.1 - Coloque aqui o link para o seu dataset escolhido no Kaggle.

# %%
#https://www.kaggle.com/mattcarter865/mines-vs-rocks

# %% [markdown]
# 1.1.1 - Descreva sobre o que é base de dados.

# %%
#Prediction Metal or Stone from Sonar Return Dataset
#Problem Statement
#The problem is to predict metal or rock objects from sonar feedback data. Each pattern is a set of 60 numbers in the range of 0.0 to 1.0. Each number represents the energy within a given frequency band, integrated over a given period of time. The label associated with each record contains the letter R if the object is a rock and M if it is a mine (metal cylinder).

#Description of the dataset:
#The numbers in the features are in ascending order of aspect angle, but do not directly encode the angle.

# %% [markdown]
# 1.1.2 - Se você fez em grupo, quais os nomes dos componentes do seu grupo?

# %% [markdown]
# 1.2 - Após tratada, criar uma pasta no seu GoogleDrive e disponibilizar o link do arquivo de sua base (csv, xlsx, etc) para ser importado no seu código.

# %%
https://github.com/fernandoquinellato/luiz.gc.lasalleAv2.2021/blob/main/sonar.csv

# %% [markdown]
# ## Criar um código usando o Jupyter Notebook e responder (através de código) às seguintes questões:

# %% [markdown]
# # Questão 2 - valor (0,5)

# %% [markdown]
# 2.1 - Importar os modulos python para machine learn e carregar o arquivo
#
# ** Sugestão se for do tipo xlsx, usar o read_excel do pandas
# import pandas as pd
# dt = pd.read_excel("meuarquivo.xlsx")

# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
# %matplotlib inline
sonar_data = pd.read_csv("https://raw.githubusercontent.com/fernandoquinellato/luiz.gc.lasalleAv2.2021/main/sonar.csv", header=None)

# %% [markdown]
# 2.2 - Exibir os primeiros registros desta tabela.

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %% [markdown]
# 2.3 - De que se trata esse banco de dados? e que tipo de previsão pode ser feito com ele?

# %%
#Trata-se do uso de sonar para a predição entre rocha e metal

# %% [markdown]
# # Questão 3 - valor (1,5)

# %% [markdown]
# Utilizando as terminologias de Machine Learning(features e observações):

# %% [markdown]
# 3.1 - Quantas "features" têm nessa base de dados?

# %%
# 61 features

# %% [markdown]
# 3.2 - Quantas observações têm nessa base de dados?

# %%
# 208 observações

# %% [markdown]
# 3.3 - Separe o que é entrada (features) do seu dataset na variável X, e exiba.

# %%
sonar_data.describe()
# Out:
#                0           1           2   ...          57          58          59
# count  208.000000  208.000000  208.000000  ...  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832  ...    0.007949    0.007941    0.006507
# std      0.022991    0.032960    0.038428  ...    0.006470    0.006181    0.005031
# min      0.001500    0.000600    0.001500  ...    0.000300    0.000100    0.000600
# 25%      0.013350    0.016450    0.018950  ...    0.003600    0.003675    0.003100
# 50%      0.022800    0.030800    0.034300  ...    0.005800    0.006400    0.005300
# 75%      0.035550    0.047950    0.057950  ...    0.010350    0.010325    0.008525
# max      0.137100    0.233900    0.305900  ...    0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %% [markdown]
# 3.4 - Separe o que é saída (target/resposta) do seu dataset na variável y, e exiba.

# %%
sonar_data.groupby(60).mean()
# Out:
#           0         1         2   ...        57        58        59
# 60                                ...
# M   0.034989  0.045544  0.050720  ...  0.009060  0.008695  0.006930
# R   0.022498  0.030303  0.035951  ...  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %% [markdown]
# # Questão 4 - valor (1,5)

# %% [markdown]
# 4.1 - Utilizando a sua base, faça um treinamento e uma previsão, usando o algoritmo de clsssificação de sua escolha.

# %%
X = sonar_data.drop(columns=60, axis=1)
Y = sonar_data[60]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, stratify=Y, random_state=1)
print(X.shape, X_train.shape, X_test.shape)
print(X_train, Y_train)
# Out:
# (208, 60) (187, 60) (21, 60)
#          0       1       2       3   ...      56      57      58      59
# 115  0.0414  0.0436  0.0447  0.0844  ...  0.0141  0.0077  0.0246  0.0198
# 38   0.0123  0.0022  0.0196  0.0206  ...  0.0113  0.0058  0.0047  0.0071
# 56   0.0152  0.0102  0.0113  0.0263  ...  0.0037  0.0011  0.0034  0.0033
# 123  0.0270  0.0163  0.0341  0.0247  ...  0.0138  0.0094  0.0105  0.0093
# 18   0.0270  0.0092  0.0145  0.0278  ...  0.0120  0.0132  0.0070  0.0088
# ..      ...     ...     ...     ...  ...     ...     ...     ...     ...
# 140  0.0412  0.1135  0.0518  0.0232  ...  0.0095  0.0225  0.0098  0.0085
# 5    0.0286  0.0453  0.0277  0.0174  ...  0.0057  0.0027  0.0051  0.0062
# 154  0.0117  0.0069  0.0279  0.0583  ...  0.0020  0.0062  0.0026  0.0052
# 131  0.1150  0.1163  0.0866  0.0358  ...  0.0190  0.0141  0.0068  0.0086
# 203  0.0187  0.0346  0.0168  0.0177  ...  0.0065  0.0115  0.0193  0.0157
#
# [187 rows x 60 columns] 115    M
# 38     R
# 56     R
# 123    M
# 18     R
#       ..
# 140    M
# 5      R
# 154    M
# 131    M
# 203    M
# Name: 60, Length: 187, dtype: object

# %% [markdown]
# # Questão 5 - valor (1,5)

# %% [markdown]
# Usando o método de avaliação de acurácia (Train test split), Escolha outros 2 algoritmos de classificação e calcule a acurácia dos mesmos.

# %% [markdown]
# 5.2 - Acurácia usando o algoritmo 1 ?

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print("Accuracy on training data :" , training_data_accuracy)
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print("Accuracy on test data :" , test_data_accuracy)
# Out:
# Accuracy on training data : 0.8342245989304813
# Accuracy on test data : 0.7619047619047619

# %% [markdown]
# 5.3 - Acurácia usando o algoritmo 2 ?

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size= 0.1, stratify= y, random_state= 1)
print(X.shape, X_train.shape, X_test.shape)
model = LogisticRegression()
model.fit(X_train, y_train)
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)
print('Accuracy on training data: ', training_data_accuracy)
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)
print('Accuracy on test data: ', test_data_accuracy)
# Out:
# (208, 60) (187, 60) (21, 60)
# Accuracy on training data:  0.8342245989304813
# Accuracy on test data:  0.7619047619047619

# %% [markdown]
# 5.4 - De acordo com seus resultados anteriores, qual dos 2 algoritmos é mais eficiente?

# %%
#Os dois são igualmente eficientes.

# %% [markdown]
# # Questão 6 - valor (1,5)

# %% [markdown]
# 6 - Faça um visualização auto-explicativa da sua base de dados utilizando o matplotlib. Coloque o código e a visualização abaixo.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
model = Sequential()
model.add(Dense(100, input_shape=(X_train.shape[1],), activation = 'relu'))
model.add(Dense(20, activation = 'relu'))
model.add(Dropout(0.7))
model.add(Dense(500, activation = 'relu'))
model.add(Dropout(0.7))
model.add(Dense(500, activation = 'relu'))
model.add(Dropout(0.7))
model.add(Dense(200, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(y_train.shape[1], activation = 'sigmoid'))

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
cl = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=50)
fig, ax = plt.subplots(figsize=(15,5))

plt.plot(cl.history['accuracy'], label='accuracy')
plt.plot(cl.history['val_accuracy'], label='val_accuracy', linestyle='--')
plt.plot(cl.history['loss'], label='loss')
plt.plot(cl.history['val_loss'], label='val_loss', linestyle='--')
plt.legend()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               6100
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                2020
# _________________________________________________________________
# dropout (Dropout)            (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               10500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 200)               100200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 402
# =================================================================
# Total params: 369,722
# Trainable params: 369,722
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 6/6 [==============================] - 1s 48ms/step - loss: 0.7520 - accuracy: 0.4337 - val_loss: 0.6886 - val_accuracy: 0.5952
# Epoch 2/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6992 - accuracy: 0.5060 - val_loss: 0.6856 - val_accuracy: 0.5476
# Epoch 3/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.7032 - accuracy: 0.5663 - val_loss: 0.6817 - val_accuracy: 0.5476
# Epoch 4/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6843 - accuracy: 0.5422 - val_loss: 0.6780 - val_accuracy: 0.5476
# Epoch 5/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6699 - accuracy: 0.5602 - val_loss: 0.6746 - val_accuracy: 0.5476
# Epoch 6/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.7113 - accuracy: 0.5241 - val_loss: 0.6732 - val_accuracy: 0.5952
# Epoch 7/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6840 - accuracy: 0.5602 - val_loss: 0.6693 - val_accuracy: 0.5952
# Epoch 8/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6745 - accuracy: 0.5422 - val_loss: 0.6659 - val_accuracy: 0.5952
# Epoch 9/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6540 - accuracy: 0.6265 - val_loss: 0.6568 - val_accuracy: 0.5714
# Epoch 10/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6351 - accuracy: 0.6084 - val_loss: 0.6459 - val_accuracy: 0.6190
# Epoch 11/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6169 - accuracy: 0.6205 - val_loss: 0.6317 - val_accuracy: 0.6905
# Epoch 12/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5833 - accuracy: 0.6506 - val_loss: 0.6164 - val_accuracy: 0.7381
# Epoch 13/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5760 - accuracy: 0.7289 - val_loss: 0.5999 - val_accuracy: 0.7619
# Epoch 14/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5803 - accuracy: 0.7349 - val_loss: 0.5838 - val_accuracy: 0.8095
# Epoch 15/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5267 - accuracy: 0.7651 - val_loss: 0.5622 - val_accuracy: 0.7857
# Epoch 16/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5033 - accuracy: 0.7892 - val_loss: 0.5403 - val_accuracy: 0.8333
# Epoch 17/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4925 - accuracy: 0.8072 - val_loss: 0.5175 - val_accuracy: 0.8333
# Epoch 18/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4723 - accuracy: 0.7831 - val_loss: 0.4981 - val_accuracy: 0.8333
# Epoch 19/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4219 - accuracy: 0.8795 - val_loss: 0.4833 - val_accuracy: 0.8333
# Epoch 20/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4182 - accuracy: 0.8554 - val_loss: 0.4647 - val_accuracy: 0.8095
# Epoch 21/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4035 - accuracy: 0.8735 - val_loss: 0.4506 - val_accuracy: 0.8095
# Epoch 22/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4675 - accuracy: 0.8614 - val_loss: 0.4236 - val_accuracy: 0.8095
# Epoch 23/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3594 - accuracy: 0.9036 - val_loss: 0.4002 - val_accuracy: 0.8810
# Epoch 24/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3665 - accuracy: 0.8855 - val_loss: 0.3811 - val_accuracy: 0.8810
# Epoch 25/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3094 - accuracy: 0.9157 - val_loss: 0.3696 - val_accuracy: 0.8571
# Epoch 26/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3061 - accuracy: 0.9217 - val_loss: 0.3632 - val_accuracy: 0.8571
# Epoch 27/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2588 - accuracy: 0.9337 - val_loss: 0.3759 - val_accuracy: 0.8333
# Epoch 28/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3061 - accuracy: 0.8976 - val_loss: 0.3666 - val_accuracy: 0.8571
# Epoch 29/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1981 - accuracy: 0.9578 - val_loss: 0.3489 - val_accuracy: 0.8810
# Epoch 30/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2426 - accuracy: 0.9157 - val_loss: 0.3528 - val_accuracy: 0.8810
# Epoch 31/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2295 - accuracy: 0.9217 - val_loss: 0.3440 - val_accuracy: 0.8810
# Epoch 32/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1817 - accuracy: 0.9518 - val_loss: 0.3367 - val_accuracy: 0.8571
# Epoch 33/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1926 - accuracy: 0.9277 - val_loss: 0.3724 - val_accuracy: 0.8571
# Epoch 34/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2017 - accuracy: 0.9398 - val_loss: 0.4755 - val_accuracy: 0.8571
# Epoch 35/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2013 - accuracy: 0.9337 - val_loss: 0.4621 - val_accuracy: 0.8333
# Epoch 36/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2410 - accuracy: 0.9096 - val_loss: 0.4012 - val_accuracy: 0.8571
# Epoch 37/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1245 - accuracy: 0.9699 - val_loss: 0.3782 - val_accuracy: 0.8810
# Epoch 38/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1494 - accuracy: 0.9458 - val_loss: 0.4122 - val_accuracy: 0.8333
# Epoch 39/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1559 - accuracy: 0.9578 - val_loss: 0.4756 - val_accuracy: 0.8571
# Epoch 40/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2021 - accuracy: 0.9217 - val_loss: 0.4328 - val_accuracy: 0.8571
# Epoch 41/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2072 - accuracy: 0.9337 - val_loss: 0.4252 - val_accuracy: 0.8571
# Epoch 42/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1254 - accuracy: 0.9699 - val_loss: 0.4538 - val_accuracy: 0.8571
# Epoch 43/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1493 - accuracy: 0.9639 - val_loss: 0.4980 - val_accuracy: 0.8571
# Epoch 44/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1819 - accuracy: 0.9458 - val_loss: 0.5317 - val_accuracy: 0.8571
# Epoch 45/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1607 - accuracy: 0.9578 - val_loss: 0.5474 - val_accuracy: 0.8571
# Epoch 46/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1483 - accuracy: 0.9578 - val_loss: 0.5509 - val_accuracy: 0.8571
# Epoch 47/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1477 - accuracy: 0.9578 - val_loss: 0.5816 - val_accuracy: 0.8571
# Epoch 48/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1690 - accuracy: 0.9458 - val_loss: 0.6271 - val_accuracy: 0.8333
# Epoch 49/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1399 - accuracy: 0.9639 - val_loss: 0.6712 - val_accuracy: 0.8095
# Epoch 50/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1507 - accuracy: 0.9578 - val_loss: 0.6178 - val_accuracy: 0.8333

# %%
*** Envie o link do seu Github com essa resposta no Classroom
